# %%
txt = "Hello World"[::-1]
print(txt)
# Out:
# dlroW olleH

# %%
from rauth import OAuth2Service
import json
service = OAuth2Service(
 client_id = '81527cff06843c8634fdc09e8ac0abefb46ac849f38fe1e431c2ef2106796384',
 client_secret = 'c7257eb71a564034f9419ee651c7d0e5f7aa6bfbd18bafb5c5c033b093bb2fa3',
 access_token_url = "https://owner-api.teslamotors.com/oauth/token",
 authorize_url = "https://owner-api.teslamotors.com/oauth/token",
 base_url = "https://owner-api.teslamotors.com/",
 )

# %%
import json
email = 'yuanjing.xu@gmail.com'
password = 'rsWdlt.35'
data = {"grant_type": "password",
        "client_id": '81527cff06843c8634fdc09e8ac0abefb46ac849f38fe1e431c2ef2106796384',
        "client_secret": 'c7257eb71a564034f9419ee651c7d0e5f7aa6bfbd18bafb5c5c033b093bb2fa3',
        "email": email,
        "password": password}

def new_decoder(payload):
    return json.loads(payload.decode('utf-8'))

session = service.get_auth_session(data=data, decoder=new_decoder)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\python\lib\site-packages\rauth\service.py in process_token_request(r, decoder, *args)
#      20         data = decoder(r.content)
# ---> 21         return tuple(data[key] for key in args)
#      22     except KeyError as e:  # pragma: no cover
#
# e:\python\lib\site-packages\rauth\service.py in <genexpr>(.0)
#      20         data = decoder(r.content)
# ---> 21         return tuple(data[key] for key in args)
#      22     except KeyError as e:  # pragma: no cover
#
# KeyError: 'access_token'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-375f8b47d6c3> in <module>
#      11     return json.loads(payload.decode('utf-8'))
#      12
# ---> 13 session = service.get_auth_session(data=data, decoder=new_decoder)
#
# e:\python\lib\site-packages\rauth\service.py in get_auth_session(self, method, **kwargs)
#     554         :type \*\*kwargs: dict
#     555         '''
# --> 556         session = self.get_session(self.get_access_token(method, **kwargs))
#     557
#     558         if self.access_token_response:
#
# e:\python\lib\site-packages\rauth\service.py in get_access_token(self, method, decoder, key, **kwargs)
#     540         '''
#     541         r = self.get_raw_access_token(method, **kwargs)
# --> 542         access_token, = process_token_request(r, decoder, key)
#     543         return access_token
#     544
#
# e:\python\lib\site-packages\rauth\service.py in process_token_request(r, decoder, *args)
#      22     except KeyError as e:  # pragma: no cover
#      23         bad_key = e.args[0]
# ---> 24         raise KeyError(PROCESS_TOKEN_ERROR.format(key=bad_key, raw=r.content))
#      25
#      26
#
# KeyError: 'Decoder failed to handle access_token with data as returned by provider. A different decoder may be needed. Provider returned: b\'{"response":null,"error":"Endpoint deprecated: Please update your App.","error_description":""}\''
